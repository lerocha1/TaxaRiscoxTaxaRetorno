# %%
import pandas as pd
import matplotlib.pyplot as fig
import numpy as np
from scipy.stats import norm
import math
import yfinance as yf

# %%
df = yf.download('BBAS3.SA', start='2015-01-01', end='2020-10-31').Close
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head(5)
# Out:
# Date
# 2015-01-02    22.650000
# 2015-01-05    22.180000
# 2015-01-06    22.490000
# 2015-01-07    23.480000
# 2015-01-08    23.559999
# Name: Close, dtype: float64

# %%
fig.figure(
        figsize=(12,8),
        facecolor='gray')
Ax=fig.axes()
Ax.set_facecolor('gray')
fig.plot(df)
fig.xlabel('Periodo')
fig.ylabel('Valor R$')
fig.legend('BBSA3')
fig.title('Evolução ação BBSA3', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Evolução ação BBSA3')

# %%
n=len(df)
prec=df

# %%
ri=prec/prec.shift(1)-1

# %%
sigma=ri.std()
sigma
# Out:
# 0.0018624654464370958

# %%
sigma
# Out:
# 0.0018624654464370958
